# %% [markdown]
# ## Se seguirá este plan de análisis para este conjunto de datos, centrados principalmente en la regresión lineal.
#
# **Análisis de Variables Individuales**:
#
# *Distribuciones Univariables*: Examina la distribución de cada variable numérica usando histogramas y para las categóricas, gráficos de barras.
#
# *Estadísticas Descriptivas*: Calcula estadísticas descriptivas como media, mediana, rango, y desviación estándar para tener una idea de la centralidad y dispersión de cada variable.
#
# **Análisis de Relaciones entre Variables**:
#
# *Gráficos de Dispersión*: Utiliza gráficos de dispersión para observar las relaciones entre las variables numéricas, especialmente con la variable objetivo 'SalePrice'.
#
# *Gráficos de Caja*: Para las variables categóricas, los gráficos de caja pueden ayudar a visualizar la distribución de 'SalePrice' en diferentes categorías.
#
# **Análisis de Correlación**:
#
# *Matriz de Correlación*: Ya has generado una matriz de correlación. Ahora, identifica las variables que tienen una fuerte correlación con la variable objetivo y entre sí.
#
# *Mapa de Calor*: Utiliza el mapa de calor para identificar patrones de correlación que podrían indicar multicolinealidad o relaciones potencialmente útiles para la modelización.
# Análisis de Valores Atípicos:
#
# *Identificación de Outliers*: Utiliza gráficos de caja o IQR (Rango Intercuartílico) para identificar y tratar con valores atípicos que podrían afectar el rendimiento de los modelos predictivos.
# Análisis de Valores Faltantes:
#
# *Mapa de Calor de Valores Faltantes*: Visualiza los valores faltantes para entender si el patrón de datos faltantes es aleatorio o no.
#
# *Imputación o Eliminación*: Decide si imputar los valores faltantes usando métodos como la media, mediana, o modas, o eliminar las filas/columnas con demasiados valores faltantes.
#
# *Transformaciones de Variables*:
#
# *Normalización o Estandarización*: Aplica transformaciones para normalizar o estandarizar las variables, especialmente si planeas usar modelos que asumen normalidad o son sensibles a la escala de las características.
#
# *Transformaciones Logarítmicas*: Para las variables sesgadas, considera aplicar transformaciones logarítmicas para reducir el sesgo.
#
# **Creación de Variables Derivadas**:
#
# *Ingeniería de Características*: Crea nuevas variables que puedan capturar mejor la información para los modelos predictivos, como la edad de la propiedad desde su construcción o remodelación.
# Visualización Avanzada:
#
# *Gráficos Interactivos*: Utiliza herramientas como Plotly o Bokeh para crear visualizaciones interactivas que permitan una exploración más profunda de los datos.
#
# **Documentación**:
#
# *Registro de Hallazgos*: Documenta tus hallazgos y observaciones a medida que avanzas en el EDA para referencias futuras y para compartir con otros stakeholders.

# %%
from Analysis_module import Data_module
from Analysis_module import Graphics

data_module = Data_module()
visualizer = Graphics()
data_module.load_boston_housing_data()
visualizer.plot_numeric_variables(data_module.boston_housing_x)
# Out:
# hi from graphics
# /home/armsjs/anaconda3/envs/DataSciencePortfolio/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
# ...

# %%
visualizer.plot_numeric_variables(data=data_module.boston_housing_x, plot_type='box', y=data_module.boston_housing_y)

# %%
visualizer.plot_numeric_variables(data=data_module.boston_housing_x, plot_type='scatter', y=data_module.boston_housing_y)

# %%
visualizer.plot_correlation_matrix(data_module.boston_housing_x)
