# %%
from Report_module import Report_module
import pandas as pd
import numpy as np
from graphviz import Source

report = Report_module()
# Out:
# hi from analysis
# hi from graphics
# hi from report module

# %%
report.data_module.apple_quality_data.shape
# Out:
# (4001, 9)

# %%
report.data_module.student_data.shape
# Out:
# (4424, 35)

# %%
report.data_module.apple_quality_data.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
report.data_module.student_data.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    evening attendance  Previous qualification  Nacionality  \
# 0                   1                       1            1
# 1                   1                       1            1
# 2                   1                       1            1
# 3                   1                       1            1
# 4                   0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
report.data_module.student_data.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        evening attendance  Previous qualification  Nacionality  \
# count         4424.000000             4424.000000  4424.000000
# mean             0.890823                2.531420     1.254521
# std              0.311897                3.963707     1.748447
# min              0.000000                1.000000     1.000000
# ...

# %%
report.data_module.student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   evening attendance                              4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
X_student_data = report.data_module.student_data.iloc[:, [7, 8]]

# %%
X_student_data.isna().sum()
# Out:
# Mother's qualification    0
# Father's qualification    0
# dtype: int64

# %%
y_student_data = report.data_module.student_data.iloc[:, 34]

# %%
# y_student_data[y_student_data == 'Graduate'] = 'Active'
# y_student_data[y_student_data == 'Dropout'] = 'Inactive'
# y_student_data[y_student_data == 'Enrolled'] = 'Active'
# y_student_data = np.array(y_student_data.map({'Active': 1, 'Inactive': 0}))

# %%
y_student_data.value_counts()
# Out:
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: Output, dtype: int64

# %%
type(y_student_data)
# Out:
# pandas.core.series.Series

# %%
svm = report.analysis_module.get_svm_instance(X=X_student_data, y=y_student_data, kernel='rbf', gamma='scale', C=1.5)
report.graphics_module.plot_decision_boundary(svm=svm, response_method='predict', alpha=0.8, xlabel='Parents qualifications', ylabel='Graduated', X=X_student_data)

# %%
tree_instance = report.analysis_module.get_tree_instance(X=X_student_data, y=y_student_data, criterion='log_loss', max_depth=32)
report.graphics_module.plot_tree(tree_instance=tree_instance, feature_names=np.array(X_student_data.columns), target=y_student_data, file_name='students_tree.dot')

with open('students_tree.dot') as f:
    dot_graph = f.read()

Source(dot_graph)

# %%
X_student_data
# Out:
#       Mother's qualification  Father's qualification
# 0                         13                      10
# 1                          1                       3
# 2                         22                      27
# 3                         23                      27
# 4                         22                      28
# ...                      ...                     ...
# 4419                       1                       1
# 4420                       1                       1
# 4421                      22                      27
# 4422                      22                      27
# 4423                      23                      27
#
# [4424 rows x 2 columns]

# %%
y_student_data[y_student_data == 'Graduate'] = 1
y_student_data[y_student_data == 'Dropout'] = 0
y_student_data[y_student_data == 'Enrolled'] = 1

tree_instance = report.analysis_module.get_tree_instance(X=X_student_data, y=y_student_data, criterion='squared_error', max_depth=32, use_regressor=True)
report.graphics_module.plot_tree(tree_instance=tree_instance, feature_names=np.array(X_student_data.columns), target=y_student_data, file_name='students_tree.dot')

with open('students_tree.dot') as f:
    dot_graph = f.read()

Source(dot_graph)
# Out:
# /tmp/ipykernel_41602/3877068870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_student_data[y_student_data == 'Graduate'] = 1
# /tmp/ipykernel_41602/3877068870.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_student_data[y_student_data == 'Dropout'] = 0
# /tmp/ipykernel_41602/3877068870.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_student_data[y_student_data == 'Enrolled'] = 1
